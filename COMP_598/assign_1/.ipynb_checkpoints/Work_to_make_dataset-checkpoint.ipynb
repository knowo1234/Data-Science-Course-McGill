# %%
import pandas as pd

#save filename to a variable called filename
filename=r'C:/Users/xsnow/Desktop/School/Semester 7/Comp 598/comp598-2021/hw1/submission_template/data/IRAhandle_tweets_1.csv'

tweets=pd.read_csv(filename) #read the file into the code

# %%
tweets=tweets.head(10000) #look at the first 10000 tweets
tweets
# Out:
#       external_author_id    author  \
# 0     906000000000000000    10_GOP
# 1     906000000000000000    10_GOP
# 2     906000000000000000    10_GOP
# 3     906000000000000000    10_GOP
# 4     906000000000000000    10_GOP
# ...                  ...       ...
# 9995          3312143142  4MYSQUAD
# 9996          3312143142  4MYSQUAD
# 9997          3312143142  4MYSQUAD
# 9998          3312143142  4MYSQUAD
# 9999          3312143142  4MYSQUAD
#
#                                                 content         region  \
# 0     "We have a sitting Democrat US Senator on tria...        Unknown
# 1     Marshawn Lynch arrives to game in anti-Trump s...        Unknown
# 2     Daughter of fallen Navy Sailor delivers powerf...        Unknown
# 3     JUST IN: President Trump dedicates Presidents ...        Unknown
# 4     19,000 RESPECTING our National Anthem! #StandF...        Unknown
# ...                                                 ...            ...
# ...

# %%
tweets_df=pd.DataFrame(tweets)

# %%
tweets_df = tweets_df[tweets_df.language == 'English']
tweets_df.shape
# Out:
# (5345, 21)

# %%
tweets_df
# Out:
#       external_author_id    author  \
# 0     906000000000000000    10_GOP
# 1     906000000000000000    10_GOP
# 2     906000000000000000    10_GOP
# 3     906000000000000000    10_GOP
# 4     906000000000000000    10_GOP
# ...                  ...       ...
# 9994          3312143142  4MYSQUAD
# 9996          3312143142  4MYSQUAD
# 9997          3312143142  4MYSQUAD
# 9998          3312143142  4MYSQUAD
# 9999          3312143142  4MYSQUAD
#
#                                                 content         region  \
# 0     "We have a sitting Democrat US Senator on tria...        Unknown
# 1     Marshawn Lynch arrives to game in anti-Trump s...        Unknown
# 2     Daughter of fallen Navy Sailor delivers powerf...        Unknown
# 3     JUST IN: President Trump dedicates Presidents ...        Unknown
# 4     19,000 RESPECTING our National Anthem! #StandF...        Unknown
# ...                                                 ...            ...
# ...

# %%
tweets_df.content[340:344].str.contains("\?")
# Out:
# 340    False
# 341    False
# 342     True
# 343    False
# Name: content, dtype: bool

# %%
tweets_df.content[340:343]
# Out:
# 340    For those who don't let the truth get in the w...
# 341    A great thread to fully understand the situati...
# 342    We're baaaaack. What did we miss?  #FreeTennessee
# Name: content, dtype: object

# %%
tweets_df = tweets_df[~tweets_df.content.str.contains("\?")]

# %%
tweets_df.shape
# Out:
# (4802, 21)

# %%
tweets_df
# Out:
#       external_author_id    author  \
# 0     906000000000000000    10_GOP
# 1     906000000000000000    10_GOP
# 2     906000000000000000    10_GOP
# 3     906000000000000000    10_GOP
# 4     906000000000000000    10_GOP
# ...                  ...       ...
# 9992          3312143142  4MYSQUAD
# 9996          3312143142  4MYSQUAD
# 9997          3312143142  4MYSQUAD
# 9998          3312143142  4MYSQUAD
# 9999          3312143142  4MYSQUAD
#
#                                                 content         region  \
# 0     "We have a sitting Democrat US Senator on tria...        Unknown
# 1     Marshawn Lynch arrives to game in anti-Trump s...        Unknown
# 2     Daughter of fallen Navy Sailor delivers powerf...        Unknown
# 3     JUST IN: President Trump dedicates Presidents ...        Unknown
# 4     19,000 RESPECTING our National Anthem! #StandF...        Unknown
# ...                                                 ...            ...
# ...

# %%
tweets_df.content.str.contains("\?")
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9992    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: content, Length: 4802, dtype: bool
